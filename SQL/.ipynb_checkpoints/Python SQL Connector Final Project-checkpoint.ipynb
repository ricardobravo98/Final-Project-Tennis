# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns

#%matplotlib inline
password = getpass.getpass()
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sys'
engine = create_engine(connection_string)
# Out:
# ········

# %%
query = ''

data = pd.read_sql_query(query, engine)
data.head()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.10/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
# ...

# %%
data = pd.read_csv("Ranking_stats_v2.csv")

# Table name in the database
table_name = "tennis_players"

# Load data into the database table
data.to_sql(table_name, con=engine, if_exists='replace', index=False)
# Out:
# 500

# %%
host = '127.0.0.1'
user = 'root'
password = 'Potito33.'
database = 'sys'
csv_file_path = 'Ranking_stats_v2.csv'

# Connect to the database
connection = pymysql.connect(host=host, user=user, password=password, database=database)
cursor = connection.cursor()

# Truncate the table (optional - if you want to start fresh)
# cursor.execute('TRUNCATE TABLE tennis_players;')

# Read data from the CSV file and insert into the table
with open(csv_file_path, 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    next(csvreader)  # Skip header row
    for row in csvreader:
        # Replace 'tennis_players' with your actual table name
        query = 'INSERT INTO tennis_players (ranking, players, atp_points, ages, ... ) VALUES (%s, %s, %s, %s, ...);'
        cursor.execute(query, row)

# Commit the changes and close the connection
connection.commit()
cursor.close()  # Close the cursor
connection.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 21
#      18     for row in csvreader:
#      19         # Replace 'tennis_players' with your actual table name
#      20         query = 'INSERT INTO tennis_players (ranking, players, atp_points, ages, ... ) VALUES (%s, %s, %s, %s, ...);'
# ---> 21         cursor.execute(query, row)
#      23 # Commit the changes and close the connection
#      24 connection.commit()
#
# File ~/anaconda3/lib/python3.10/site-packages/pymysql/cursors.py:151, in Cursor.execute(self, query, args)
#     148 while self.nextset():
#     149     pass
# --> 151 query = self.mogrify(query, args)
#     153 result = self._query(query)
#     154 self._executed = query
#
# File ~/anaconda3/lib/python3.10/site-packages/pymysql/cursors.py:129, in Cursor.mogrify(self, query, args)
#     126 conn = self._get_db()
#     128 if args is not None:
# ...
